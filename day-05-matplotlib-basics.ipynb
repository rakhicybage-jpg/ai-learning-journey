# %%
import matplotlib.pyplot as plt
import pandas as pd

days = [1,2,3,4,5]
views = [100,200,150,300,500]
#create line chart
#plt.plot(days, views, color="green", marker="o", linestyle="--")
plt.title("Blogs views per day!!")
plt.xlabel("Days")
plt.ylabel("Views")
#plt.show

#Create bar chart
authors = ["Rakhi", "Jhon", "Sara"]
total_views = [2370, 5300, 450]
#plt.bar(authors, total_views, color="blue")
plt.title("Total Views per author")
plt.xlabel("Authors")
plt.ylabel("Total Views")
#plt.show

#create histogram
# Load Titanic data
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df["Age"]= df["Age"].fillna(df["Age"].mean())
# Plot age distribution
plt.hist(df["Age"], bins=20, color="orange", edgecolor="black")
plt.title("Age Distribution of Titanic Passengers")
plt.xlabel("Age")
plt.ylabel("Number of Passengers")
plt.show()
#pie chart
survived = df["Survived"].value_counts()
plt.pie(survived, 
        labels=["Died", "Survived"], 
        colors=["red", "green"],
        autopct="%1.1f%%")
plt.title("Titanic Survival Rate")
plt.show()
#
survival_by_sex = df.groupby("Sex")["Survived"].mean()

#plt.bar(survival_by_sex.index, survival_by_sex.values, color=["pink", "blue"])
plt.title("Survival Rate by Gender")
plt.xlabel("Gender")
plt.ylabel("Survival Rate")
#plt.show()
#
survival_by_class = df.groupby("Pclass")["Survived"].mean()

plt.bar(survival_by_class.index, survival_by_class.values, 
        color=["gold", "silver", "brown"])
plt.title("Survival Rate by Class")
plt.xlabel("Passenger Class")
plt.ylabel("Survival Rate")
plt.show()
